# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'crop_yield.csv'
crop_yield_data = pd.read_csv(file_path)
display(crop_yield_data)
# Calculate the average yield per year
avg_yield_per_year = crop_yield_data.groupby('Crop_Year')['Yield'].mean()

# Plotting the average yield per year
plt.figure(figsize=(10, 6))
plt.plot(avg_yield_per_year.index, avg_yield_per_year.values, marker='o', linestyle='-', color='b', label='Average Yield')

# Adding plot details
plt.title('Average Crop Yield Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Yield (metric tons per hectare)')
plt.legend(loc='upper right')
plt.grid(True)
plt.xticks(rotation=45)

# Adding some basic text to indicate notable years
plt.text(2000, avg_yield_per_year.loc[2000], 'Year 2000', ha='center', color='red')
plt.text(2010, avg_yield_per_year.loc[2010], 'Year 2010', ha='center', color='green')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...
